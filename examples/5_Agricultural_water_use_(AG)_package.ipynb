# %% [markdown]
# # MODFLOW-NWT Agricultural Water Use package (AG) example
#
# The Agricultural water use package allows users to specify irrigation from wells and stream segments within MODFLOW-NWT and GSFLOW.
#
# In this notebook examples of how to read in the AG package using pygsflow are presented

# %%
import os
import gsflow
import flopy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading a pre-built AG package file
#
# We can load the AG package as part of a GSFLOW or modflow model automatically, or load the AG package individually using the `ModflowAg` class.
#
# Here we present the second option for illustration.

# %%
# define workspace and our ag_file name
workspace = "./data/sagehen/modflow"
ag_file = "sagehen.awu"
dis_file = "saghen_ag.dis"

# %% [markdown]
# Let's create an empty `Modflow` model object so we can begin adding packages to it

# %%
ml = gsflow.modflow.Modflow(modelname="sagehen_example", model_ws=workspace)
ml
# Out:
# MODFLOW 0 layer(s), 0 row(s), 0 column(s), 0 stress period(s)

# %% [markdown]
# Next we can add the DIS file to the `Modflow` object. This will give us information about the model size, and the length of the model.
#
# ### Note: We are going to use `flopy` to read in the dis file and add it to the `Modflow` object

# %%
dis = flopy.modflow.ModflowDis.load(os.path.join(workspace, dis_file), model=ml)
ml
# Out:
# MODFLOW 2 layer(s), 77 row(s), 84 column(s), 344 stress period(s)

# %% [markdown]
# From the output, we can see that the `ModflowDis` object has been loaded and added to the `Modflow` model
#
# ### Now let's load the AG package using pygsflow's `ModflowAg.load()` method
#
# The `load()` method has a few important parameters.
#
# `f` : the AG package file name
#
# `model` : the `gsflow.modflow.Modflow` model object
#
# `nper` : number of stress periods in the model
#
# `method` : can be `gsflow` or `modflow`, if this is being used as part of a `gsflow` project, select `gsflow` (default)

# %%
ag = gsflow.modflow.ModflowAg.load(os.path.join(workspace, ag_file), model=ml, nper=dis.nper, method='gsflow')
# now let's look at the well_list
ag.well_list
# Out:
# rec.array([(1, 38, 53, -500.), (1, 37, 50, -500.), (1, 37, 51, -500.),
#            (1, 37, 52, -500.), (1, 37, 54, -500.), (1, 37, 55, -500.),
#            (1, 37, 56, -500.), (1, 37, 57, -500.), (1, 37, 58, -500.),
#            (1, 36, 50, -500.), (1, 36, 51, -500.), (1, 36, 52, -500.),
#            (1, 36, 55, -500.), (1, 35, 50, -500.), (1, 35, 56, -500.),
#            (1, 35, 57, -500.), (1, 35, 58, -500.), (1, 34, 52, -500.),
#            (1, 34, 53, -500.), (1, 34, 55, -500.), (1, 34, 56, -500.),
#            (1, 34, 57, -500.), (1, 34, 58, -500.), (1, 33, 48, -500.),
#            (1, 33, 49, -500.), (1, 33, 50, -500.), (1, 33, 51, -500.),
#            (1, 33, 52, -500.), (1, 33, 54, -500.), (1, 33, 55, -500.),
#            (1, 33, 56, -500.), (1, 33, 57, -500.), (1, 33, 58, -500.),
#            (1, 33, 53, -500.)],
#           dtype=[('k', '<i4'), ('i', '<i4'), ('j', '<i4'), ('flux', '<f8')])

# %% [markdown]
# ### the well_list is stored as a flopy compatible recarray, we can also look at some of the other datatypes
#
# other datatypes include:
#
# `irrdiversion` which hold the irrdiversion blocks from the AG package
#
# `irrwell` which holds the irrwell blocks from the AG package
#
# `supwell` which holds the supwell blocks from the AG package

# %%
# irrdiversion
irs = ag.irrdiversion

# irrwell
irr = ag.irrwell

# supwell
sup = ag.supwell

print(irr)
# Out:
# {0: rec.array([],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 1: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 2: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 3: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 4: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 5: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 6: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 7: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 8: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 9: rec.array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#            ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#            ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#            ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#            ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#            ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#            ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#            ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#            ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#            ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#            (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#            (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#            (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#            (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#            (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#            (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#            (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#            (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#            (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#            (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#            (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#            (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#            (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#            (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#            (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#            (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#            (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#            (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#            (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#            (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#            (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#            (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#            (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#            (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 10: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 11: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 12: rec.array([],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 13: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 14: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 15: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 16: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 17: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 18: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 19: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 20: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 21: rec.array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#            ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#            ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#            ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#            ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#            ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#            ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#            ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#            ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#            ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#            (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#            (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#            (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#            (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#            (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#            (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#            (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#            (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#            (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#            (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#            (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#            (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#            (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#            (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#            (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#            (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#            (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#            (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#            (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#            (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#            (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#            (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#            (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#            (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 22: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 23: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 24: rec.array([],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 25: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 26: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 27: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 28: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 29: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 30: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 31: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 32: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 33: rec.array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#            ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#            ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#            ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#            ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#            ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#            ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#            ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#            ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#            ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#            (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#            (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#            (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#            (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#            (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#            (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#            (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#            (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#            (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#            (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#            (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#            (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#            (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#            (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#            (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#            (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#            (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#            (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#            (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#            (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#            (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#            (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#            (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#            (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 34: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 35: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 36: rec.array([],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 37: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 38: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 39: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 40: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 41: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 42: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 43: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 44: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 45: rec.array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#            ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#            ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#            ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#            ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#            ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#            ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#            ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#            ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#            ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#            (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#            (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#            (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#            (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#            (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#            (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#            (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#            (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#            (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#            (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#            (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#            (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#            (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#            (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#            (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#            (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#            (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#            (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#            (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#            (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#            (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#            (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#            (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#            (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 46: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 47: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 48: rec.array([],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 49: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 50: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 51: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 52: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 53: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 54: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 55: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 56: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 57: rec.array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#            ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#            ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#            ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#            ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#            ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#            ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#            ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#            ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#            ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#            (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#            (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#            (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#            (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#            (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#            (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#            (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#            (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#            (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#            (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#            (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#            (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#            (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#            (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#            (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#            (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#            (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#            (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#            (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#            (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#            (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#            (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#            (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#            (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 58: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 59: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 60: rec.array([],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 61: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 62: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 63: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 64: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 65: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 66: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 67: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 68: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 69: rec.array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#            ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#            ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#            ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#            ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#            ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#            ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#            ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#            ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#            ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#            (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#            (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#            (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#            (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#            (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#            (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#            (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#            (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#            (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#            (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#            (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#            (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#            (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#            (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#            (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#            (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#            (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#            (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#            (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#            (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#            (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#            (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#            (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#            (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 70: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 71: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
# ...
#            ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#            ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#            ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#            ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#            ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#            ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#            ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#            ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#            ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#            (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#            (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#            (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#            (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#            (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#            (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#            (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#            (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#            (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#            (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#            (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#            (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#            (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#            (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#            (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#            (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#            (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#            (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#            (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#            (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#            (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#            (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#            (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#            (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 322: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 323: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 324: rec.array([],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 325: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 326: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 327: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 328: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 329: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 330: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 331: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 332: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 333: rec.array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#            ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#            ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#            ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#            ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#            ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#            ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#            ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#            ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#            ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#            (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#            (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#            (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#            (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#            (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#            (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#            (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#            (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#            (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#            (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#            (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#            (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#            (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#            (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#            (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#            (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#            (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#            (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#            (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#            (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#            (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#            (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#            (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#            (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 334: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 335: array([( 0, 1, -1.e+10, 1.e+10, 3055, -1, 1., 0.85),
#        ( 1, 1, -1.e+10, 1.e+10, 2973, -1, 1., 0.85),
#        ( 2, 1, -1.e+10, 1.e+10, 2974, -1, 1., 0.85),
#        ( 3, 1, -1.e+10, 1.e+10, 2975, -1, 1., 0.85),
#        ( 4, 1, -1.e+10, 1.e+10, 2977, -1, 1., 0.85),
#        ( 5, 1, -1.e+10, 1.e+10, 2978, -1, 1., 0.85),
#        ( 6, 1, -1.e+10, 1.e+10, 2979, -1, 1., 0.85),
#        ( 7, 1, -1.e+10, 1.e+10, 2980, -1, 1., 0.85),
#        ( 8, 1, -1.e+10, 1.e+10, 2981, -1, 1., 0.85),
#        ( 9, 1, -1.e+10, 1.e+10, 2894, -1, 1., 0.85),
#        (10, 1, -1.e+10, 1.e+10, 2895, -1, 1., 0.85),
#        (11, 1, -1.e+10, 1.e+10, 2896, -1, 1., 0.85),
#        (12, 1, -1.e+10, 1.e+10, 2899, -1, 1., 0.85),
#        (13, 1, -1.e+10, 1.e+10, 2815, -1, 1., 0.85),
#        (14, 1, -1.e+10, 1.e+10, 2821, -1, 1., 0.85),
#        (15, 1, -1.e+10, 1.e+10, 2822, -1, 1., 0.85),
#        (16, 1, -1.e+10, 1.e+10, 2823, -1, 1., 0.85),
#        (17, 1, -1.e+10, 1.e+10, 2738, -1, 1., 0.85),
#        (18, 1, -1.e+10, 1.e+10, 2739, -1, 1., 0.85),
#        (19, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.85),
#        (20, 1, -1.e+10, 1.e+10, 2742, -1, 1., 0.85),
#        (21, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.85),
#        (22, 1, -1.e+10, 1.e+10, 2744, -1, 1., 0.85),
#        (23, 1, -1.e+10, 1.e+10, 2655, -1, 1., 0.85),
#        (24, 1, -1.e+10, 1.e+10, 2656, -1, 1., 0.85),
#        (25, 1, -1.e+10, 1.e+10, 2657, -1, 1., 0.85),
#        (26, 1, -1.e+10, 1.e+10, 2658, -1, 1., 0.85),
#        (27, 1, -1.e+10, 1.e+10, 2659, -1, 1., 0.85),
#        (28, 1, -1.e+10, 1.e+10, 2661, -1, 1., 0.85),
#        (29, 1, -1.e+10, 1.e+10, 2662, -1, 1., 0.85),
#        (30, 1, -1.e+10, 1.e+10, 2663, -1, 1., 0.85),
#        (31, 1, -1.e+10, 1.e+10, 2664, -1, 1., 0.85),
#        (32, 1, -1.e+10, 1.e+10, 2665, -1, 1., 0.85),
#        (33, 1, -1.e+10, 1.e+10, 2660, -1, 1., 0.85)],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 336: rec.array([],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 337: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 338: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 339: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 340: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 341: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 342: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])), 343: array([],
#       dtype=(numpy.record, [('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]))}

# %% [markdown]
# ## Now let's illustrate how to build a AG package from scratch
#
# First let's get some empty data-types to store data in using `ModflowAG.get_empty()`

# %%
well_list = gsflow.modflow.ModflowAg.get_empty(numrecords=2, block="well")

# %% [markdown]
# Let's create 2 wells now and add it to our well_list

# %%
# layer, row, column, maximum_flux
temp = [[1, 38, 53, -500.],
        [1, 38, 54, -1000.]]

for ix, well in enumerate(temp):
    well_list[ix] = tuple(well)
    
well_list
# Out:
# rec.array([(1, 38, 53,  -500.), (1, 38, 54, -1000.)],
#           dtype=[('k', '<i4'), ('i', '<i4'), ('j', '<i4'), ('flux', '<f8')])

# %% [markdown]
# Now let's create two irrigation cells that are linked to our wells

# %%
irrwell0 = gsflow.modflow.ModflowAg.get_empty(numrecords=2, maxells=1, block="irrwell_gsflow")

# let's look at the dtypes we need 
irrwell0.dtype.names
# Out:
# ('wellid',
#  'numcell',
#  'period',
#  'triggerfact',
#  'hru_id0',
#  'dum0',
#  'eff_fact0',
#  'field_fact0')

# %% [markdown]
# Let's create two irrigation cell links and add it to our irrwell
#
# Note: -1e+10 and 1e+10 are used to indicate that there is no data for this (unused variables), see Agricultural Water Use Package for MODFLOW-NWT for more infromation about the variables...

# %%
# 'wellid', 'numcell', 'period', 'triggerfact', 'hru_id0', 'dum0', 'eff_fact0', 'field_fact0'
temp = [[1, 1, -1e+10, 1e+10, 2741, -1, 1., 0.5],
        [2, 1, -1e+10, 1e+10, 2743, -1, 1., 0.5]]

for ix, irr in enumerate(temp):
    irrwell0[ix] = tuple(irr)

irrwell0
# Out:
# rec.array([(1, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.5),
#            (2, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.5)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])

# %% [markdown]
# Since irrwell is stress period data, this needs to be made for each stress period in the model and placed in a dictionary with the format `{kper : data}`
#
# We are just going to reuse the same dataset for a three stress period example

# %%
kper = 3

irrwell = {}
for per in range(kper):
    irrwell[per] = irrwell0
    
irrwell
# Out:
# {0: rec.array([(1, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.5),
#             (2, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.5)],
#            dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]),
#  1: rec.array([(1, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.5),
#             (2, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.5)],
#            dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]),
#  2: rec.array([(1, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.5),
#             (2, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.5)],
#            dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])}

# %% [markdown]
# # Now let's start building our new `ModflowAg` object using the data we just created
#
# ### We will need to start by specifying the option block using the new `OptionBlock` utility in FloPy
#
# let's create an empty options block and start filling out the data

# %%
options = flopy.utils.OptionBlock(options_line="", package=gsflow.modflow.ModflowAg)
options
# Out:
# OPTIONS
# END

# %% [markdown]
# First let's specify the number of wells in the AG package (see Agricultural Water Use Package doc, for variable names)

# %%
options.maxwell = True
options.nummaxwell = 2

# we can see that the maxwell option and nummaxwell have been added to the options block
print(options)
# Out:
# OPTIONS
# MAXWELL 2
# END

# %% [markdown]
# Now let's specify our irriagation well information

# %%
options.irrigation_well = True
options.numirrwells = 2
options.maxcellswell = 1

options
# Out:
# OPTIONS
# IRRIGATION_WELL 2 1
# MAXWELL 2
# END

# %% [markdown]
# Finally let's specify the unit number to write CBC output for wells to

# %%
options.wellcbc = True
options.unitcbc = 99

options
# Out:
# OPTIONS
# IRRIGATION_WELL 2 1
# MAXWELL 2
# WELLCBC 99
# END

# %% [markdown]
# ### Now we're ready to create our new `ModflowAg` package object

# %%
new_ag = gsflow.modflow.ModflowAg(ml, options=options, well_list=well_list, irrwell=irrwell)
new_ag
# Out:
# WARNING: unit 69 of package AG already in use
# ****Warning -- two packages of the same type:  <class 'gsflow.modflow.mfawu.ModflowAg'> <class 'gsflow.modflow.mfawu.ModflowAg'>
# replacing existing Package...
#     The ModflowAg class is used to build read, write, and edit data
#     from the MODFLOW-NWT AG package.
#
#     Parameters
#     ----------
#     model : gsflow.modflow.Modflow object
#         model object
#     extension : str, optional
#         default is .ag
#     options : flopy.utils.OptionBlock object
#         option block utility from flopy
#     unitnumber : list, optional
#         fortran unit number for modflow, default 69
#     filenames : list, optional
#         file name for ModflowAg package to write input
#
#      _name = AG
#  _nper = 344 ('int)
#  _parent = MODFLOW 2 layer(s), 77 row(s), 84 column(s), 344 stress period(s) ('gsflow.modflow.mf.Modflow)
#  accel = None ('NoneType)
#  acceptable_dtypes (list, items = 3
#  allowDuplicates = False ('bool)
#  bc_color = black ('str)
#  diversionirrlist = False ('bool)
#  diversionlist = False ('bool)
#  etdemand = False ('bool)
#  extra =
#  file_name = sagehen_example.ag
#  fn_path = ./data/sagehen/modflow\sagehen_example.ag ('str)
#  irrdiversion = None ('NoneType)
#  irrigation_diversion = False ('bool)
#  irrigation_well = True ('bool)
#  irrwell = {0: rec.array([(1, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.5),
#            (2, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.5)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 1: rec.array([(1, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.5),
#            (2, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.5)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')]), 2: rec.array([(1, 1, -1.e+10, 1.e+10, 2741, -1, 1., 0.5),
#            (2, 1, -1.e+10, 1.e+10, 2743, -1, 1., 0.5)],
#           dtype=[('wellid', '<i4'), ('numcell', '<i4'), ('period', '<f8'), ('triggerfact', '<f8'), ('hru_id0', '<i4'), ('dum0', '<i4'), ('eff_fact0', '<f8'), ('field_fact0', '<f8')])} ('dict)
#  maxcellsdiversion = None ('NoneType)
#  maxcellswell = 1 ('int)
#  maxdiversions = None ('NoneType)
#  maxval = None ('NoneType)
#  maxwell = True ('bool)
#  noprint = False ('bool)
#  numirrdiversions = None ('NoneType)
#  numirrwells = 2 ('int)
#  nummaxwell = 2 ('int)
#  numsupwells = None ('NoneType)
#  numtab = None ('NoneType)
#  options = OPTIONS
# IRRIGATION_WELL 2 1
# MAXWELL 2
# WELLCBC 99
# END
#  ('flopy.utils.optionblock.OptionBlock)
#  phiramp = None ('NoneType)
#  supplemental_well = False ('bool)
#  supwell = None ('NoneType)
#  tabfiles = False ('bool)
#  time_series = None ('NoneType)
#  timeseries_diversion = False ('bool)
#  timeseries_diversionet = False ('bool)
#  timeseries_well = False ('bool)
#  timeseries_wellet = False ('bool)
#  trigger = False ('bool)
#  unit_diversionirrlist = None ('NoneType)
#  unit_diversionlist = None ('NoneType)
#  unit_number = 69
#  unit_wellirrlist = None ('NoneType)
#  unit_welllist = None ('NoneType)
#  unitcbc = 99 ('int)
#  well_list (array, shape = 2,)
#  wellcbc = True ('bool)
#  wellirrlist = False ('bool)
#  welllist = False ('bool)

# %% [markdown]
# ### Finally we can write the new_file to disk

# %%
new_ag.write_file()
